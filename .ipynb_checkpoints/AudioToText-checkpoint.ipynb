# %%
import speech_recognition as sr
from os import path
from pydub import AudioSegment

# %%
# # obtain path to "english.wav" in the same folder as this script
# from os import path
# AUDIO_FILE = path.join(path.dirname(path.realpath("Audio")), "test.wav")
# # AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "french.aiff")
# # AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "chinese.flac")

# # use the audio file as the audio source
# r = sr.Recognizer()
# with sr.AudioFile(AUDIO_FILE) as source:
#     audio = r.record(source)  # read the entire audio file

# %%
# t1 = 1000 #Works in milliseconds
# t2 = 2 * 1000
# audio = AudioSegment.from_wav("michealis,chan.wav")
# newAudio = newAudio[t1:t2]
# newAudio.export('test1.wav', format="wav") #Exports to a wav file in the current path.

# %%
file = "ChelseaEdwards"
audio = AudioSegment.from_wav(file + ".wav")

# %%
print(audio.duration_seconds)
time = 0
files = []
count = 0
interval = 5000
while time < audio.duration_seconds*1000:
    (audio[max(0, time-200):time+interval]+15).export("file" + str(count) + ".wav", format="wav")
    files.append('file' + str(count) + ".wav")
    time +=interval
    count+=1
# Out:
# 1528.895986394558

# %%
print(files)
# Out:
# ['file0.wav', 'file1.wav', 'file2.wav', 'file3.wav', 'file4.wav', 'file5.wav', 'file6.wav', 'file7.wav', 'file8.wav', 'file9.wav', 'file10.wav', 'file11.wav', 'file12.wav', 'file13.wav', 'file14.wav', 'file15.wav', 'file16.wav', 'file17.wav', 'file18.wav', 'file19.wav', 'file20.wav', 'file21.wav', 'file22.wav', 'file23.wav', 'file24.wav', 'file25.wav', 'file26.wav', 'file27.wav', 'file28.wav', 'file29.wav', 'file30.wav', 'file31.wav', 'file32.wav', 'file33.wav', 'file34.wav', 'file35.wav', 'file36.wav', 'file37.wav', 'file38.wav', 'file39.wav', 'file40.wav', 'file41.wav', 'file42.wav', 'file43.wav', 'file44.wav', 'file45.wav', 'file46.wav', 'file47.wav', 'file48.wav', 'file49.wav', 'file50.wav', 'file51.wav', 'file52.wav', 'file53.wav', 'file54.wav', 'file55.wav', 'file56.wav', 'file57.wav', 'file58.wav', 'file59.wav', 'file60.wav', 'file61.wav', 'file62.wav', 'file63.wav', 'file64.wav', 'file65.wav', 'file66.wav', 'file67.wav', 'file68.wav', 'file69.wav', 'file70.wav', 'file71.wav', 'file72.wav', 'file73.wav', 'file74.wav', 'file75.wav', 'file76.wav', 'file77.wav', 'file78.wav', 'file79.wav', 'file80.wav', 'file81.wav', 'file82.wav', 'file83.wav', 'file84.wav', 'file85.wav', 'file86.wav', 'file87.wav', 'file88.wav', 'file89.wav', 'file90.wav', 'file91.wav', 'file92.wav', 'file93.wav', 'file94.wav', 'file95.wav', 'file96.wav', 'file97.wav', 'file98.wav', 'file99.wav', 'file100.wav', 'file101.wav', 'file102.wav', 'file103.wav', 'file104.wav', 'file105.wav', 'file106.wav', 'file107.wav', 'file108.wav', 'file109.wav', 'file110.wav', 'file111.wav', 'file112.wav', 'file113.wav', 'file114.wav', 'file115.wav', 'file116.wav', 'file117.wav', 'file118.wav', 'file119.wav', 'file120.wav', 'file121.wav', 'file122.wav', 'file123.wav', 'file124.wav', 'file125.wav', 'file126.wav', 'file127.wav', 'file128.wav', 'file129.wav', 'file130.wav', 'file131.wav', 'file132.wav', 'file133.wav', 'file134.wav', 'file135.wav', 'file136.wav', 'file137.wav', 'file138.wav', 'file139.wav', 'file140.wav', 'file141.wav', 'file142.wav', 'file143.wav', 'file144.wav', 'file145.wav', 'file146.wav', 'file147.wav', 'file148.wav', 'file149.wav', 'file150.wav', 'file151.wav', 'file152.wav', 'file153.wav', 'file154.wav', 'file155.wav', 'file156.wav', 'file157.wav', 'file158.wav', 'file159.wav', 'file160.wav', 'file161.wav', 'file162.wav', 'file163.wav', 'file164.wav', 'file165.wav', 'file166.wav', 'file167.wav', 'file168.wav', 'file169.wav', 'file170.wav', 'file171.wav', 'file172.wav', 'file173.wav', 'file174.wav', 'file175.wav', 'file176.wav', 'file177.wav', 'file178.wav', 'file179.wav', 'file180.wav', 'file181.wav', 'file182.wav', 'file183.wav', 'file184.wav', 'file185.wav', 'file186.wav', 'file187.wav', 'file188.wav', 'file189.wav', 'file190.wav', 'file191.wav', 'file192.wav', 'file193.wav', 'file194.wav', 'file195.wav', 'file196.wav', 'file197.wav', 'file198.wav', 'file199.wav', 'file200.wav', 'file201.wav', 'file202.wav', 'file203.wav', 'file204.wav', 'file205.wav', 'file206.wav', 'file207.wav', 'file208.wav', 'file209.wav', 'file210.wav', 'file211.wav', 'file212.wav', 'file213.wav', 'file214.wav', 'file215.wav', 'file216.wav', 'file217.wav', 'file218.wav', 'file219.wav', 'file220.wav', 'file221.wav', 'file222.wav', 'file223.wav', 'file224.wav', 'file225.wav', 'file226.wav', 'file227.wav', 'file228.wav', 'file229.wav', 'file230.wav', 'file231.wav', 'file232.wav', 'file233.wav', 'file234.wav', 'file235.wav', 'file236.wav', 'file237.wav', 'file238.wav', 'file239.wav', 'file240.wav', 'file241.wav', 'file242.wav', 'file243.wav', 'file244.wav', 'file245.wav', 'file246.wav', 'file247.wav', 'file248.wav', 'file249.wav', 'file250.wav', 'file251.wav', 'file252.wav', 'file253.wav', 'file254.wav', 'file255.wav', 'file256.wav', 'file257.wav', 'file258.wav', 'file259.wav', 'file260.wav', 'file261.wav', 'file262.wav', 'file263.wav', 'file264.wav', 'file265.wav', 'file266.wav', 'file267.wav', 'file268.wav', 'file269.wav', 'file270.wav', 'file271.wav', 'file272.wav', 'file273.wav', ...

# %%
def toText(file, r):
        # recognize speech using Google Speech Recognition
    try:
        # for testing purposes, we're just using the default API key
        # to use another API key, use `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
        # instead of `r.recognize_google(audio)`
        return r.recognize_google(file)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))

# %%
def toTextSphinx(file, r):
    # recognize speech using Sphinx
    try:
        return r.recognize_sphinx(file)
    except sr.UnknownValueError:
        print("Sphinx could not understand audio")
    except sr.RequestError as e:
        print("Sphinx error; {0}".format(e))

# %%
text = []
count = 0
r = sr.Recognizer()
for f in files:
    r.energy_threshold = 10
    AUDIO_FILE = path.join(path.dirname(path.realpath("Audio")), f)
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    text.append(toText(audio, r))
    print(str(count) + " " + str(text[count]))
    count += 1
# Out:
# Google Speech Recognition could not understand audio
# 0 None
# 1 hi everyone it's been tears your house here at Millennial commute join me
# 2 every week or conversations on College admissions and career planning whether you are looking to get in
# 3 is your green stool find your passion or just take his career to the next level I asked
# 4 questions will give you the answers you need from interviews with top performers from around the world
# 5 the short track full episodes this show is dedicated to give you the tools you need to pee
# 6 we're happy and fulfilled career so enjoy Today Show
# 7 today we've got an incredibly exciting conversation
# 8 with one of my friends who's out in sunny California her name is Chelsea
# 9 the Edwards doing some very exciting things she graduated recently from MIT
# 10 and now is at Caltech with Pasadena right
# 11 very very excited to have her on the show so I just
# 12 Epicurious will first Chelsea thanks for coming on the show
# 13 so you're a PhD student at Caltech recently graduated from MIT
# 14 chemical engineering so could you just tell us a little bit more about yourself
# 15 yeah sure I'm from Champaign Illinois which is basically we're up
# 16 university is in the US but I went to
# 17 Boston at MIT for undergrad and just became interested in chemical engineering
# 18 because it basically is a field that especially at the undergraduate
# 19 level combines chemistry and physics and biology
# 20 the application so if you don't
# 21 yeah and I really loved it so I wanted to keep doing
# 22 search in that area so now I'm going to tell
# 23 just like me dropping the Midwest Eye you said Champaign Illinois
# 24 singing affect the way you thought about colleges in education in general did being in the same
# 25 city is like a giant University your priorities
# 26 yeah I'm definitely I would say it champagne is bae
# 27 college town so it has a great Engineering University but it's pretty small
# 28 also basically there's a lot of resources there for students who are MO
# 29 motivated however I think fit in the midwest there tends to be more of an inch
# 30 stay at College where you grew up and
# 31 since my mom is both of my parents worked in Silicon Valley and
# 32 California
# 33 since my the rest of my family isn't really from the Midwest
# 34 I think my parents were always like yeah just tried to go elsewhere for college
# 35 okay so yeah but I think definitely
# 36 that I had access to growing up in like a small town with a lot of rain
# 37 resources was awesome cuz it's hard to find that concentration of available opportunity
# 38 in a big City where everybody wants them absolutely absolutely
# 39 motivating reasons for me doing what I do
# 40 because having also grown up in a small town where there wasn't quite
# 41 abundance of resources to put it kindly I had to do a lot of work on my
# 42 happy now to be able to be in a position where I can help people who are
# 43 maybe not so fortunate in terms of getting information about colleges and so
# 44 I first found out about you because you actually posted your resume
# 45 Keon 4 in response to a question about what were your credentials to get into
# 46 posted my resume on quora is kind of like a late-night like
# 47 truth or dare
# 48 completely
# 49 something like that
# 50 your resume is like holy crap in the rib blew up for a reason because
# 51 all these things I would like that's you know that's like Hermione and Harry Potter when she get it
# 52 change your so she can be taken like six different classes at one time is what
# 53 thought about you how are you how are you able to get so involved
# 54 ischool yeah well I think if I'm being perfectly honest
# 55 you kind of have to have a team of eight so I guess you don't have to
# 56 that my family was always there to support me the whole time
# 57 like my mom was on board with this idea
# 58 that if I was really successful at a number of things like most importantly
# 59 but I could have more options for what I could do with my life later
# 60 so I think that's why she really
# 61 stop me. Work hard in like study and
# 62 piano by the time then I was in highschool I was just
# 63 like ahead and those things and so it was easier to just
# 64 be able to spend a little bit last time on them that I otherwise would have but then also just
# 65 study classes more so
# 66 Foundation that's one thing that I had going for me even if even if I didn't necessarily have
# 67 resource that I did have a good mom
# 68 but I know my mom might be listening to this episode someday but she off
# 69 I always made sure that my brothers were reading books getting involved in things like that's obviously
# 70 helped out and made us more more ambitious and more motivate
# 71 to expand and further our studies what was your initial
# 72 motivation in applying to MIT and I'm curious where else you were looking at
# 73 actually yeah and I did want to say though that like
# 74 what your parents want like I think that just my own motivation was
# Google Speech Recognition could not understand audio
# 75 None
# 76 don't despair if your parents if you don't have like it
# 77 resources that are used to like you can still do stuff
# 78 definitely why did I fight in my school so actually I
# 79 I want to go to Princeton for a while I guess for a couple of years
# Google Speech Recognition could not understand audio
# 80 None
# 81 like Junior spring so it was rather late I think compared
# 82 what people think about or when they start thinking about it but
# 83 yeah and
# 84 local school
# 85 I got into both and then I really wanted to go to Princeton but
# 86 I think it's hard to tell if you're not directly familiar with the school
# 87 and so I was just looking at the ranking and I was like well do you know
# 88 Percy of Illinois even though it doesn't have this the same like
# 89 Princeton wood was actually better in bioengineering
# 90 mom so I sort of had this dilemma like well I could go to Princeton but then that's all
# Google Speech Recognition could not understand audio
# 91 None
# 92 might as well just a bunch of other schools that are
# 93 for people to get into
# Google Speech Recognition could not understand audio
# 94 None
# 95 Cornell engineering physics program
# Google Speech Recognition could not understand audio
# 96 None
# 97 I guess they all thought that I was good enough and so
# 98 really likes in my keys live
# 99 Venus and I felt that they were making more down-to-earth than all the other IV Plus
# 100 so that I could maybe come out as more of a
# Google Speech Recognition could not understand audio
# 101 None
# Google Speech Recognition could not understand audio
# 102 None
# 103 I think you might be the first person I've heard labeling labeling MIT is it down
# 104 regular person school but I'm glad
# 105 MIT is pretentious I'll be able to tell them that it's actually a perfect place for people
# Google Speech Recognition could not understand audio
# 106 None
# 107 we get like an elevator pitch on my high school students would want to go there maybe
# 108 set of Harvard righties or whatever like
# 109 right next door at home
# 110 it's just
# 111 I think in most cases the number of schools that people are interested in
# Google Speech Recognition could not understand audio
# 112 None
# 113 how many people are in a situation where I could
# 114 all of the schools that I had considered may be wanting to go to
# 115 I guess if you were in that situation
# 116 already the University of Illinois and all these other schools had better engine
# 117 according to
# 118 so I think I guess it's a bit difficult to answer that question because I think each individual
# 119 probably need something different
# 120 so I guess if you think about MIT admissions
# 121 they basically just take the top people that perform in the international
# Google Speech Recognition could not understand audio
# 122 None
# 123 then some other people and not necessarily like just doing well
# Google Speech Recognition could not understand audio
# 124 None
# 125 the other people did that they didn't feel like I was able to do more research and undergrad
# 126 sorry I was able to do more research in high school
# 127 roommate freshman year was like one the one female
# 128 International physics Olympiad
# Google Speech Recognition could not understand audio
# 129 None
# 130 and I tested out of all of the calculus
# 131 so I was still comparing myself to her and she was comparing herself to me and I
# 132 I think that that's just a common experience that a lot of people have so I can
# 133 describe
# 134 screen orientation the president of MIT is like how many of you guys like
# 135 confident that you know why we accept
# Google Speech Recognition could not understand audio
# 136 None
# 137 a lot of people going with those type of feelings and then maybe after they
# 138 graduate and get into the real world
# 139 like okay maybe I have had some I don't know better
# 140 teaching in some of these other people I don't know
# 141 it's just always an adventure in an expiration but yeah I think
# 142 whatever reason
# 143 Goldwater Fellowship
# 144 basically only you can only nominate for people from your school for that
# Google Speech Recognition could not understand audio
# 145 None
# Google Speech Recognition could not understand audio
# 146 None
# 147 I think that that's a common way of thinking and I've heard
# 148 things like that and yeah
# 149 now that's that's fantastic.
# 150 Robert Wells of laying it out for people I think you did a pretty great job covering all the bases
# 151 ultimately getting into chemical engineering which I heard from my friends
# 152 Cornell who majored in chemical engineering is it's like the the hardest of all
# 153 call engineering's it's the I don't know what you want to call the Moby Dick of engineering
# 154 stripper whatever but but did you keep up your steamrolling peso
# 155 activity inside and outside the classroom at MIT like you did in high school
# Google Speech Recognition could not understand audio
# 156 None
# 157 in order to be in order to get into college I had
# Google Speech Recognition could not understand audio
# 158 None
# 159 extracurriculars in number of areas that you're a well-rounded person
# Google Speech Recognition could not understand audio
# 160 None
# 161 graduate schools
# 162 next High School basically
# 163 research
# 164 it was also sort of a common feeling this
# 165 I ran into having gotten into great School
# Google Speech Recognition could not understand audio
# 166 None
# 167 what you want your job to be later so I
# Google Speech Recognition could not understand audio
# 168 None
# Google Speech Recognition could not understand audio
# 169 None
# 170 learning things basically about anything
# 171 who are becoming more focused on their jobs
# 172 start whittling down off the other extracurricular activities
# 173 I had just have one of all of those things that I
# Google Speech Recognition could not understand audio
# 174 None
# Google Speech Recognition could not understand audio
# 175 None
# 176 awesome yeah that's that's really
# 177 applying like a highlight for the audiences you knew early on that you
# 178 I want to do PhD so you're very very focused and able to
# 179 block out the noise that I would call it of the other activities
# 180 on-campus these a lot of times I feel like we used to do there can be a little bit like almost a herd mentality
# 181 party where you know people are saying you all you have to do this you have to do that you know
# 182 it's it's difficult to the tip focusing and not get caught up in that
# 183 so it's it's impressive that you were able to you know doe of full out
# 184 you did on the academics and the research
# 185 that's very true I would say there's especially when the school has a lot of resources
# 186 actually there's so many things going on
# Google Speech Recognition could not understand audio
# 187 None
# Google Speech Recognition could not understand audio
# 188 None
# 189 for telling you so that you know what you want
# 190 but if you basically just decide on like
# 191 you're just have to agree to do something
# 192 yeah
# 193 that's great that's great so I really think that's that shows discipline
# 194 good strategic thinking because I think the hardest thing for
# 195 for very smart people to do sometimes is is make decisions about
# 196 about their future it's almost ironic but when you've been trained to be good at so many different things
# 197 and you got so many different options sometimes it's tempting to you know Keith
# 198 opening up your options and trying to explore more
# 199 more
# Google Speech Recognition could not understand audio
# 200 None
# 201 you know
# Google Speech Recognition could not understand audio
# 202 None
# 203 and you can work in most areas of engineering
# Google Speech Recognition could not understand audio
# 204 None
# Google Speech Recognition could not understand audio
# 205 None
# 206 I'm just saying this is a half price
# 207 I think that people in the US
# 208 getting things done really quickly
# Google Speech Recognition could not understand audio
# 209 None
# Google Speech Recognition could not understand audio
# 210 None
# Google Speech Recognition could not understand audio
# 211 None
# 212 right now for some reason
# Google Speech Recognition could not understand audio
# 213 None
# 214 yeah that's that's right perspective because I see a lot of people and sometimes even parents
# 215 sweats like doesn't matter what you do just do something and sell
# 216 I kind of knew what I wanted to do that
# Google Speech Recognition could not understand audio
# 217 None
# 218 that's right so speaking of advice and career planning I'd be curious
# 219 what advice tips or whatever do you have for high schoolers when it comes to
# 220 applying to colleges it sounds like you were very very Hands-On in terms of doing research on
# 221 different schools
# 222 is that I think people
# 223 think about colleges backwards sometimes
# 224 X College
# Google Speech Recognition could not understand audio
# 225 None
# 226 try to do exactly what you want
# 227 do things more generally that they know college
# Google Speech Recognition could not understand audio
# 228 None
# 229 School the most and figure out what
# 230 nourishing to your soul
# Google Speech Recognition could not understand audio
# 231 None
# Google Speech Recognition could not understand audio
# 232 None
# Google Speech Recognition could not understand audio
# 233 None
# 234 berkeley weather
# 235 if you actually know what you want because
# 236 so I think that maybe that could be more helpful way of thinking of
# Google Speech Recognition could not understand audio
# 237 None
# 238 send it.
# Google Speech Recognition could not understand audio
# 239 None
# 240 chemical engineering
# 241 financially
# Google Speech Recognition could not understand audio
# 242 None
# 243 are some people that can really like
# 244 yeah I think yeah
# 245 love yourself as much as you can
# Google Speech Recognition could not understand audio
# 246 None
# 247 that's what's going to get you through college.
# 248 that's great I would I would just highlight the point of looking
# 249 Beyond like the ranking of a particular school until like the culture and the more
# 250 experience-based intangible factors and the I find that this do
# 251 things to do that will probably be the happiest and fit in the most any way in
# 252 in addition to having you know higher chance of being admitted with his sword
# 253 it's like the first thing that people are looking for so great
# 254 well those are the questions I wanted to ask about your experience
# 255 I'm serious I know you mentioned some violin playing if for sulfur
# 256 free time now how do you how do you like spending you're probably living it limited free time
# 257 so I think that my free time transition stem during college I think in high school
# 258 I really just didn't sleep that much
# Google Speech Recognition could not understand audio
# 259 None
# 260 socializing and school dances
# Google Speech Recognition could not understand audio
# 261 None
# Google Speech Recognition could not understand audio
# 262 None
# Google Speech Recognition could not understand audio
# 263 None
# 264 84 hours
# Google Speech Recognition could not understand audio
# 265 None
# Google Speech Recognition could not understand audio
# 266 None
# 267 getting older is wonderful
# 268 and also just now
# Google Speech Recognition could not understand audio
# 269 None
# 270 Saturday morning
# Google Speech Recognition could not understand audio
# 271 None
# Google Speech Recognition could not understand audio
# 272 None
# Google Speech Recognition could not understand audio
# 273 None
# 274 I think that I talk to so many
# 275 to do music seriously in high school who all told me
# Google Speech Recognition could not understand audio
# 276 None
# 277 those are basically my things I think I'm more spontaneous now about my
# Google Speech Recognition could not understand audio
# 278 None
# 279 and I want number one club in Pasadena
# 280 that's wonderful I definitely
# 281 stop playing cannot connect with you on those on the musical thing because I was always
# 282 playing trumpet to whatever in high school did a little bit in college but then
# 283 all right afterwards is just an immediate nothing so hopefully
# 284 be able to pick that up at some point in future but really enjoyed having you on the show today Channel
# 285 thanks so much for joining us here on millennial commute
# 286 thanks for absolutely absolutely so
# 287 talking with Chelsea Edwards today currently getting a Ph.D
# 288 Caltech in Pasadena California theater undergrad at MIT original
# 289 play from Champaign-Urbana Illinois I think my favorite parts of today
# 290 conversation were probably learning about how Chelsea
# 291 at such a mature approach to applying to schools I feel like a lot of people
# 292 come to me it's Earl I call you little bit confused and not really sure where you want to go and that's okay
# 293 okay but it's also sort of fun to see the perspective of someone who's like okay
# 294 I like this is sort of what I want to do here my options here the rankings and then sort of
# 295 no digging it out that way and then also enjoyed
# 296 running about you know a little bit more into the world of engineering
# 297 being outside of that never having taken any
# 298 math classes really are science classes
# 299 just made it so fun to do here that sort of perspective to self thanks everyone for
# 300 joining us on the show today August your house Ben Peters here at Millennial commute
# 301 you can check out what I'm doing on the website you can read my writing on quora
# 302 20 subscribe on iTunes I really enjoy when you guys leave me a 5-star review and
# 303 if you want to suggest any anyone to come on the show or any potential topics
# 304 please leave me a message on I www. Millennial commute. Com other
# 305 thanks for joining us on the shell and we'll see you next time bye bye

# %%
nones = [i for i in range(len(text)) if text[i] == None]
print(nones)
print(len(nones))
# Out:
# [0, 101, 129, 136, 145, 146, 160, 174, 175, 200, 204, 233, 242, 246, 259, 262, 269, 271, 272, 276]
# 20

# %%
second_pass = []
count1 = 0
for index in nones:
    if (index == 0):
        continue;
    f = files[index]
    print(f)
    (AudioSegment.from_wav(f) + 15).export("temp.wav", format="wav")
    AUDIO_FILE = path.join(path.dirname(path.realpath("Audio")), "temp.wav")
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)  # read the entire audio file
    secondTry = toText(audio, r)
    if secondTry is not None:
        text[index] = secondTry
    second_pass.append(secondTry)
    print(str(index) + " " + str(second_pass[count1]))
    count1 += 1
# Out:
# file101.wav
# Google Speech Recognition could not understand audio
# 101 None
# file129.wav
# Google Speech Recognition could not understand audio
# 129 None
# file136.wav
# Google Speech Recognition could not understand audio
# 136 None
# file145.wav
# Google Speech Recognition could not understand audio
# 145 None
# file146.wav
# Google Speech Recognition could not understand audio
# 146 None
# file160.wav
# Google Speech Recognition could not understand audio
# 160 None
# file174.wav
# Google Speech Recognition could not understand audio
# 174 None
# file175.wav
# Google Speech Recognition could not understand audio
# 175 None
# file200.wav
# Google Speech Recognition could not understand audio
# 200 None
# file204.wav
# Google Speech Recognition could not understand audio
# 204 None
# file233.wav
# Google Speech Recognition could not understand audio
# 233 None
# file242.wav
# Google Speech Recognition could not understand audio
# 242 None
# file246.wav
# Google Speech Recognition could not understand audio
# 246 None
# file259.wav
# Google Speech Recognition could not understand audio
# 259 None
# file262.wav
# Google Speech Recognition could not understand audio
# 262 None
# file269.wav
# Google Speech Recognition could not understand audio
# 269 None
# file271.wav
# Google Speech Recognition could not understand audio
# 271 None
# file272.wav
# Google Speech Recognition could not understand audio
# 272 None
# file276.wav
# Google Speech Recognition could not understand audio
# 276 None

# %%
print(text[158])
# Out:
# based on things that I thought you needed

# %%
for i in text:
    if i is not None:
        print(i)
    else:
        print("HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE")
# Out:
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# hi everyone it's been tears your house here at Millennial commute join me
# every week or conversations on College admissions and career planning whether you are looking to get in
# is your green stool find your passion or just take his career to the next level I asked
# questions will give you the answers you need from interviews with top performers from around the world
# the short track full episodes this show is dedicated to give you the tools you need to pee
# we're happy and fulfilled career so enjoy Today Show
# today we've got an incredibly exciting conversation
# with one of my friends who's out in sunny California her name is Chelsea
# the Edwards doing some very exciting things she graduated recently from MIT
# and now is at Caltech with Pasadena right
# very very excited to have her on the show so I just
# Epicurious will first Chelsea thanks for coming on the show
# so you're a PhD student at Caltech recently graduated from MIT
# chemical engineering so could you just tell us a little bit more about yourself
# yeah sure I'm from Champaign Illinois which is basically we're up
# university is in the US but I went to
# Boston at MIT for undergrad and just became interested in chemical engineering
# because it basically is a field that especially at the undergraduate
# level combines chemistry and physics and biology
# the application so if you don't
# yeah and I really loved it so I wanted to keep doing
# search in that area so now I'm going to tell
# just like me dropping the Midwest Eye you said Champaign Illinois
# singing affect the way you thought about colleges in education in general did being in the same
# city is like a giant University your priorities
# yeah I'm definitely I would say it champagne is bae
# college town so it has a great Engineering University but it's pretty small
# also basically there's a lot of resources there for students who are MO
# motivated however I think fit in the midwest there tends to be more of an inch
# stay at College where you grew up and
# since my mom is both of my parents worked in Silicon Valley and
# California
# since my the rest of my family isn't really from the Midwest
# I think my parents were always like yeah just tried to go elsewhere for college
# okay so yeah but I think definitely
# that I had access to growing up in like a small town with a lot of rain
# resources was awesome cuz it's hard to find that concentration of available opportunity
# in a big City where everybody wants them absolutely absolutely
# motivating reasons for me doing what I do
# because having also grown up in a small town where there wasn't quite
# abundance of resources to put it kindly I had to do a lot of work on my
# happy now to be able to be in a position where I can help people who are
# maybe not so fortunate in terms of getting information about colleges and so
# I first found out about you because you actually posted your resume
# Keon 4 in response to a question about what were your credentials to get into
# posted my resume on quora is kind of like a late-night like
# truth or dare
# completely
# something like that
# your resume is like holy crap in the rib blew up for a reason because
# all these things I would like that's you know that's like Hermione and Harry Potter when she get it
# change your so she can be taken like six different classes at one time is what
# thought about you how are you how are you able to get so involved
# ischool yeah well I think if I'm being perfectly honest
# you kind of have to have a team of eight so I guess you don't have to
# that my family was always there to support me the whole time
# like my mom was on board with this idea
# that if I was really successful at a number of things like most importantly
# but I could have more options for what I could do with my life later
# so I think that's why she really
# stop me. Work hard in like study and
# piano by the time then I was in highschool I was just
# like ahead and those things and so it was easier to just
# be able to spend a little bit last time on them that I otherwise would have but then also just
# study classes more so
# Foundation that's one thing that I had going for me even if even if I didn't necessarily have
# resource that I did have a good mom
# but I know my mom might be listening to this episode someday but she off
# I always made sure that my brothers were reading books getting involved in things like that's obviously
# helped out and made us more more ambitious and more motivate
# to expand and further our studies what was your initial
# motivation in applying to MIT and I'm curious where else you were looking at
# actually yeah and I did want to say though that like
# what your parents want like I think that just my own motivation was
# basically the main factor why did all of these
# don't despair if your parents if you don't have like it
# resources that are used to like you can still do stuff
# definitely why did I fight in my school so actually I
# I want to go to Princeton for a while I guess for a couple of years
# really really started thinking about colleges actually any colleges I wanted to go to
# like Junior spring so it was rather late I think compared
# what people think about or when they start thinking about it but
# yeah and
# local school
# I got into both and then I really wanted to go to Princeton but
# I think it's hard to tell if you're not directly familiar with the school
# and so I was just looking at the ranking and I was like well do you know
# Percy of Illinois even though it doesn't have this the same like
# Princeton wood was actually better in bioengineering
# mom so I sort of had this dilemma like well I could go to Princeton but then that's all
# awkward because when I get it last good of a degree also there was this question
# might as well just a bunch of other schools that are
# for people to get into
# Berkeley
# Cornell engineering physics program
# I think I just like
# I guess they all thought that I was good enough and so
# really likes in my keys live
# Venus and I felt that they were making more down-to-earth than all the other IV Plus
# so that I could maybe come out as more of a
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# similar to like the Giants
# I think you might be the first person I've heard labeling labeling MIT is it down
# regular person school but I'm glad
# MIT is pretentious I'll be able to tell them that it's actually a perfect place for people
# for normal and down-to-earth and a mighty how was the experience in could you maybe
# we get like an elevator pitch on my high school students would want to go there maybe
# set of Harvard righties or whatever like
# right next door at home
# it's just
# I think in most cases the number of schools that people are interested in
# I don't know if I can get into any of these and then they just see where they get into
# how many people are in a situation where I could
# all of the schools that I had considered may be wanting to go to
# I guess if you were in that situation
# already the University of Illinois and all these other schools had better engine
# according to
# so I think I guess it's a bit difficult to answer that question because I think each individual
# probably need something different
# so I guess if you think about MIT admissions
# they basically just take the top people that perform in the international
# Infidel gun firework
# then some other people and not necessarily like just doing well
# might not even be enough to get you in
# the other people did that they didn't feel like I was able to do more research and undergrad
# sorry I was able to do more research in high school
# roommate freshman year was like one the one female
# International physics Olympiad
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# and I tested out of all of the calculus
# so I was still comparing myself to her and she was comparing herself to me and I
# I think that that's just a common experience that a lot of people have so I can
# describe
# screen orientation the president of MIT is like how many of you guys like
# confident that you know why we accept
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# a lot of people going with those type of feelings and then maybe after they
# graduate and get into the real world
# like okay maybe I have had some I don't know better
# teaching in some of these other people I don't know
# it's just always an adventure in an expiration but yeah I think
# whatever reason
# Goldwater Fellowship
# basically only you can only nominate for people from your school for that
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# I think that that's a common way of thinking and I've heard
# things like that and yeah
# now that's that's fantastic.
# Robert Wells of laying it out for people I think you did a pretty great job covering all the bases
# ultimately getting into chemical engineering which I heard from my friends
# Cornell who majored in chemical engineering is it's like the the hardest of all
# call engineering's it's the I don't know what you want to call the Moby Dick of engineering
# stripper whatever but but did you keep up your steamrolling peso
# activity inside and outside the classroom at MIT like you did in high school
# the answer is no actually I think that
# in order to be in order to get into college I had
# based on things that I thought you needed
# extracurriculars in number of areas that you're a well-rounded person
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# graduate schools
# next High School basically
# research
# it was also sort of a common feeling this
# I ran into having gotten into great School
# show the world really care about a lot of the stuff that I did
# what you want your job to be later so I
# it matters to you on a personal level
# Stockton in making decisions or
# learning things basically about anything
# who are becoming more focused on their jobs
# start whittling down off the other extracurricular activities
# I had just have one of all of those things that I
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# awesome yeah that's that's really
# applying like a highlight for the audiences you knew early on that you
# I want to do PhD so you're very very focused and able to
# block out the noise that I would call it of the other activities
# on-campus these a lot of times I feel like we used to do there can be a little bit like almost a herd mentality
# party where you know people are saying you all you have to do this you have to do that you know
# it's it's difficult to the tip focusing and not get caught up in that
# so it's it's impressive that you were able to you know doe of full out
# you did on the academics and the research
# that's very true I would say there's especially when the school has a lot of resources
# actually there's so many things going on
# College in your schedule is more free it's more difficult to decide or
# actually important to you especially because ontology
# for telling you so that you know what you want
# but if you basically just decide on like
# you're just have to agree to do something
# yeah
# that's great that's great so I really think that's that shows discipline
# good strategic thinking because I think the hardest thing for
# for very smart people to do sometimes is is make decisions about
# about their future it's almost ironic but when you've been trained to be good at so many different things
# and you got so many different options sometimes it's tempting to you know Keith
# opening up your options and trying to explore more
# more
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# you know
# can do both of those things successfully
# and you can work in most areas of engineering
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# yeah yeah
# I'm just saying this is a half price
# I think that people in the US
# getting things done really quickly
# dad and just figure out what you want
# take some time away like that
# things can be very
# right now for some reason
# nobody's going to care about that
# yeah that's that's right perspective because I see a lot of people and sometimes even parents
# sweats like doesn't matter what you do just do something and sell
# I kind of knew what I wanted to do that
# stay focused
# that's right so speaking of advice and career planning I'd be curious
# what advice tips or whatever do you have for high schoolers when it comes to
# applying to colleges it sounds like you were very very Hands-On in terms of doing research on
# different schools
# is that I think people
# think about colleges backwards sometimes
# X College
# I want to go to jail
# try to do exactly what you want
# do things more generally that they know college
# extracurricular
# School the most and figure out what
# nourishing to your soul
# I like music for focus on whatever you're doing
# and then you can write about it because that's the whole reason
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# berkeley weather
# if you actually know what you want because
# so I think that maybe that could be more helpful way of thinking of
# turns out that for you that thing is to go to a 2-year Community College
# send it.
# literally could be the best day ever
# chemical engineering
# financially
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# are some people that can really like
# yeah I think yeah
# love yourself as much as you can
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# that's what's going to get you through college.
# that's great I would I would just highlight the point of looking
# Beyond like the ranking of a particular school until like the culture and the more
# experience-based intangible factors and the I find that this do
# things to do that will probably be the happiest and fit in the most any way in
# in addition to having you know higher chance of being admitted with his sword
# it's like the first thing that people are looking for so great
# well those are the questions I wanted to ask about your experience
# I'm serious I know you mentioned some violin playing if for sulfur
# free time now how do you how do you like spending you're probably living it limited free time
# so I think that my free time transition stem during college I think in high school
# I really just didn't sleep that much
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# socializing and school dances
# occasionally hang out with
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# stop James Sports and teams and started doing just music like once a week
# 84 hours
# eight sleep
# on the day and be productive with only a high school
# getting older is wonderful
# and also just now
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# Saturday morning
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# by taking breaks and yeah I'm trying to keep violin
# I think that I talk to so many
# to do music seriously in high school who all told me
# HI CYNTHIA/SHIRLEY MY CODE MISSED SOMETHING HERE
# those are basically my things I think I'm more spontaneous now about my
# people aren't ranking them anymore saying I go
# and I want number one club in Pasadena
# that's wonderful I definitely
# stop playing cannot connect with you on those on the musical thing because I was always
# playing trumpet to whatever in high school did a little bit in college but then
# all right afterwards is just an immediate nothing so hopefully
# be able to pick that up at some point in future but really enjoyed having you on the show today Channel
# thanks so much for joining us here on millennial commute
# thanks for absolutely absolutely so
# talking with Chelsea Edwards today currently getting a Ph.D
# Caltech in Pasadena California theater undergrad at MIT original
# play from Champaign-Urbana Illinois I think my favorite parts of today
# conversation were probably learning about how Chelsea
# at such a mature approach to applying to schools I feel like a lot of people
# come to me it's Earl I call you little bit confused and not really sure where you want to go and that's okay
# okay but it's also sort of fun to see the perspective of someone who's like okay
# I like this is sort of what I want to do here my options here the rankings and then sort of
# no digging it out that way and then also enjoyed
# running about you know a little bit more into the world of engineering
# being outside of that never having taken any
# math classes really are science classes
# just made it so fun to do here that sort of perspective to self thanks everyone for
# joining us on the show today August your house Ben Peters here at Millennial commute
# you can check out what I'm doing on the website you can read my writing on quora
# 20 subscribe on iTunes I really enjoy when you guys leave me a 5-star review and
# if you want to suggest any anyone to come on the show or any potential topics
# please leave me a message on I www. Millennial commute. Com other
# people aren't ranking them anymore saying I go

# %%
# print(len(text))
# print(len(text1))
# for i in range(len(text1)):
#     if text[i] != text1[i]:
#         print(text[i])
#         print(text1[i])

# r.

# %%
outF = open(file + ".txt", "w")
for line in text:
  # write line to output file
    if line is not None:
        outF.write(line)
        outF.write("\n")
outF.close()
